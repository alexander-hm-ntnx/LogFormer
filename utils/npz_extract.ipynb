# %%
from numpy import load
import pprint

input_path = "preprocessed_data/BGL_2k_testing_data.npz"
data = load(input_path)
lst = data.files
for item in lst:
    print(item)
    print(data[item])
    break

# with open(input_path[0:-4], "w") as f:
#     pprint.pprint(lst, stream=f)
# Out:
# x
# [[[-0.66858184 -0.22630559 -0.04185342 ...  0.26828706 -0.53020924
#    -0.24447966]
#   [-0.66858184 -0.22630559 -0.04185342 ...  0.26828706 -0.53020924
#    -0.24447966]
#   [-0.66858184 -0.22630559 -0.04185342 ...  0.26828706 -0.53020924
#    -0.24447966]
#   ...
#   [-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]
#   [-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]
#   [-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]]
#
#  [[-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]
#   [-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]
#   [-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]
#   ...
#   [-0.66858184 -0.22630559 -0.04185342 ...  0.26828706 -0.53020924
#    -0.24447966]
#   [-0.755652    0.06884377  0.16561903 ... -0.8382067  -0.6729842
#     0.019874  ]
# ...
